# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/PM_Assessment_Logs/ProcessGAN
# !ls

# %%
import os, sys
sys.path.append(os.getcwd())

from nets.process_gan_time import ProcessGAN_Time

# %%
BASE = "/content/drive/MyDrive/PM_Assessment_Logs/ProcessGAN/data/data_time/MIMICEL/data_seq"

for name in [
    "MIMICEL.txt",
    "MIMICEL_time_dif_norm.txt",
    "MIMICEL_time_duration_norm.txt"
]:
    path = f"{BASE}/{name}"
    with open(path, "r") as f:
        lines = [line.strip() for line in f if line.strip()]
    print(name, len(lines))

# %%
# !python run.py --mode act_time_loss --model trans_attn --data MIMICEL
